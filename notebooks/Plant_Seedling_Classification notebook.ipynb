# %% [markdown]
# # Plant Seedling Classification
# #### Author - github.com/tushar2704

# %% [markdown]
# ## Importing required Libraries

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import os
import pathlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import PIL

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Defining the path for test and train data

# %%
import splitfolders

input_folder = '/content/drive/MyDrive/Plant seedling Classification'
output_folder = '/content/dataset'

splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.8, .0, .2))
# Out:
# Copying files: 5544 files [01:26, 63.77 files/s]

# %%
import glob

train_length = 0
test_length = 0

for name in glob.glob('/content/dataset/train/*'):
  train_length += len(glob.glob(name+'/*.png'))

for name in glob.glob('/content/dataset/test/*'):
  test_length += len(glob.glob(name+'/*.png'))

print(train_length,test_length)
# Out:
# 4430 1114

# %% [markdown]
# ### Load using keras.preprocessing
#
# ### Creating the dataset

# %%
batch_size = 32
img_height = 120
img_width = 120

# %%
data_dir_train = '/content/dataset/train'
data_dir_test = '/content/dataset/test'

# %%
# creating train dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, validation_split=0.2, subset="training", seed=123,
                                                               image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 4430 files belonging to 12 classes.
# Using 3544 files for training.

# %%
# creating validation dataset

val_ds = tf.keras.preprocessing.image_dataset_from_directory(data_dir_train, validation_split=0.2, subset="validation", seed=123,
                                                             image_size=(img_height, img_width), batch_size=batch_size)
# Out:
# Found 4430 files belonging to 12 classes.
# Using 886 files for validation.

# %%
# Listing out all the classes of plant seedlings and store them in a list.

labels = sorted(os.listdir(data_dir_train))
print(labels)
# Out:
# ['Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed', 'Common wheat', 'Fat Hen', 'Loose Silky-bent', 'Maize', 'Scentless Mayweed', 'Shepherd’s Purse', 'Small-flowered Cranesbill', 'Sugar beet']

# %%
# creating a list which counts the number of images in each class of plant seedling
count_plot = []
for i in labels:
    count_plot.append(len(os.listdir(os.path.join(data_dir_train,i))))

# %%
count_plot
# Out:
# [247, 361, 268, 570, 202, 430, 613, 205, 485, 219, 460, 370]

# %% [markdown]
# ### Visualizing the data

# %%
# creating plot for distribution of images in each class
count_plot = np.array(count_plot)
plt.bar(labels, count_plot)
plt.xticks(rotation = 90)
plt.show()

# %%
# visualizing few images from the train data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for image, label in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image[i].numpy().astype("uint8"))
    plt.title(labels[label[i]])
    plt.axis("off")

# %% [markdown]
# ## Creating the model

# %% [markdown]
# ### Model 1
# Creating a CNN model, which can accurately detect 12 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
# specifying image dimensions with RGB channel
input_shape = (120,120,3)
# storing number of classes of plant seedlings in a variable
num_classes = 12

# creating layers for the first model using conv2D
model = Sequential()
model.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, offset=0.0, input_shape=input_shape))
model.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same'))
model.add(Activation('relu'))
# using batch normalization
model.add(BatchNormalization())
model.add(Conv2D(32, kernel_size=(3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
### Compiling the model
### choosing an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
### Training the model
epochs = 20
batch_size = 32
history = model.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/20
# 111/111 [==============================] - 58s 333ms/step - loss: 2.6055 - accuracy: 0.5093 - val_loss: 28.3399 - val_accuracy: 0.1366
# Epoch 2/20
# 111/111 [==============================] - 33s 284ms/step - loss: 0.7958 - accuracy: 0.7466 - val_loss: 28.3301 - val_accuracy: 0.1377
# Epoch 3/20
# 111/111 [==============================] - 34s 290ms/step - loss: 0.4824 - accuracy: 0.8394 - val_loss: 18.5278 - val_accuracy: 0.1377
# Epoch 4/20
# 111/111 [==============================] - 34s 283ms/step - loss: 0.3112 - accuracy: 0.8936 - val_loss: 7.6903 - val_accuracy: 0.1941
# Epoch 5/20
# 111/111 [==============================] - 30s 260ms/step - loss: 0.2760 - accuracy: 0.9027 - val_loss: 2.0814 - val_accuracy: 0.5598
# Epoch 6/20
# 111/111 [==============================] - 29s 249ms/step - loss: 0.1956 - accuracy: 0.9345 - val_loss: 11.8230 - val_accuracy: 0.2325
# Epoch 7/20
# 111/111 [==============================] - 29s 246ms/step - loss: 0.1774 - accuracy: 0.9438 - val_loss: 5.0141 - val_accuracy: 0.4074
# Epoch 8/20
# 111/111 [==============================] - 28s 243ms/step - loss: 0.1614 - accuracy: 0.9458 - val_loss: 1.7509 - val_accuracy: 0.6693
# Epoch 9/20
# 111/111 [==============================] - 28s 243ms/step - loss: 0.1741 - accuracy: 0.9438 - val_loss: 1.3729 - val_accuracy: 0.7562
# Epoch 10/20
# 111/111 [==============================] - 28s 245ms/step - loss: 0.1159 - accuracy: 0.9642 - val_loss: 1.3528 - val_accuracy: 0.7381
# Epoch 11/20
# 111/111 [==============================] - 30s 261ms/step - loss: 0.0603 - accuracy: 0.9834 - val_loss: 1.1865 - val_accuracy: 0.7980
# Epoch 12/20
# 111/111 [==============================] - 28s 245ms/step - loss: 0.0697 - accuracy: 0.9791 - val_loss: 1.1527 - val_accuracy: 0.8036
# Epoch 13/20
# 111/111 [==============================] - 28s 241ms/step - loss: 0.0896 - accuracy: 0.9715 - val_loss: 1.3962 - val_accuracy: 0.7675
# Epoch 14/20
# 111/111 [==============================] - 28s 241ms/step - loss: 0.1188 - accuracy: 0.9656 - val_loss: 1.7347 - val_accuracy: 0.7506
# Epoch 15/20
# 111/111 [==============================] - 29s 248ms/step - loss: 0.1681 - accuracy: 0.9554 - val_loss: 3.4493 - val_accuracy: 0.5666
# Epoch 16/20
# 111/111 [==============================] - 30s 260ms/step - loss: 0.1000 - accuracy: 0.9681 - val_loss: 2.0816 - val_accuracy: 0.7201
# Epoch 17/20
# 111/111 [==============================] - 28s 242ms/step - loss: 0.1202 - accuracy: 0.9642 - val_loss: 1.4891 - val_accuracy: 0.7630
# Epoch 18/20
# 111/111 [==============================] - 28s 241ms/step - loss: 0.1020 - accuracy: 0.9757 - val_loss: 1.5137 - val_accuracy: 0.7833
# Epoch 19/20
# 111/111 [==============================] - 28s 241ms/step - loss: 0.0807 - accuracy: 0.9777 - val_loss: 2.1287 - val_accuracy: 0.7156
# Epoch 20/20
# 111/111 [==============================] - 28s 241ms/step - loss: 0.0747 - accuracy: 0.9805 - val_loss: 2.2587 - val_accuracy: 0.6964

# %%
### visualizing the model results.
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Results from Model 1
# 1. The accuracy of the model for the Training data set is at 98%. But the Validation accuracy is not in par with the training accuracy.
# It is only at 69%.
# 2. The validation loss as observed is very high.This could also be indicative of some Overfitting in the model.
# 3. We could add some Dropout layers and remove the BatchNormalization layers to avoid overfitting to some extent

# %% [markdown]
# ### Model 2
# #### Removing Batch Normalization and Adding Dropouts.
# Removing Batch Normalization for this layer and adding dropouts after every hidden layer to avoid overfitting

# %%
input_shape = (120,120,3)
num_classes = 12

model2 = Sequential()
# adding layers for normalizing the images between 0 and 1
model2.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, offset=0.0, input_shape=input_shape))
model2.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same'))
model2.add(Activation('relu'))
model2.add(Conv2D(32, kernel_size=(3, 3)))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.20))

model2.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model2.add(Activation('relu'))
model2.add(Conv2D(64, (3, 3)))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.20))

model2.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
model2.add(Activation('relu'))
model2.add(Conv2D(128, (3, 3)))
model2.add(Activation('relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.20))

model2.add(Flatten())
model2.add(Dense(256))
model2.add(Activation('relu'))
model2.add(Dropout(0.20))
model2.add(Dense(num_classes))
model2.add(Activation('softmax'))

# %%
### compiling the model
### choosing an appropirate optimiser and loss function
opt = Adam(0.001) # specifying the optimizer used for the model
model2.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# specifying the format in which model needs to be saved
model_name = 'Seed2' + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)
 # giving the file path
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{val_loss:.5f}-.h5'
# Creating the call back for saving only the best models
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
# creating the callback for early stopping
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)

callbacks_list = [checkpoint, early_stopping]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
### training the model and using callback parameter to save the best model
epochs = 50
batch_size = 32
history = model2.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 110/111 [============================>.] - ETA: 0s - loss: 2.4481 - accuracy: 0.1290
# Epoch 1: val_loss improved from inf to 2.41363, saving model to Seed2/model-00001-2.44801-2.41363-.h5
# 111/111 [==============================] - 31s 245ms/step - loss: 2.4480 - accuracy: 0.1292 - val_loss: 2.4136 - val_accuracy: 0.1377
# Epoch 2/50
# 111/111 [==============================] - ETA: 0s - loss: 2.4251 - accuracy: 0.1284
# Epoch 2: val_loss did not improve from 2.41363
# 111/111 [==============================] - 29s 248ms/step - loss: 2.4251 - accuracy: 0.1284 - val_loss: 2.4139 - val_accuracy: 0.1377
# Epoch 3/50
# 111/111 [==============================] - ETA: 0s - loss: 2.3941 - accuracy: 0.1704
# Epoch 3: val_loss improved from 2.41363 to 2.15964, saving model to Seed2/model-00003-2.39407-2.15964-.h5
# 111/111 [==============================] - 28s 242ms/step - loss: 2.3941 - accuracy: 0.1704 - val_loss: 2.1596 - val_accuracy: 0.3081
# Epoch 4/50
# 111/111 [==============================] - ETA: 0s - loss: 1.8004 - accuracy: 0.3764
# Epoch 4: val_loss improved from 2.15964 to 1.44560, saving model to Seed2/model-00004-1.80040-1.44560-.h5
# 111/111 [==============================] - 29s 248ms/step - loss: 1.8004 - accuracy: 0.3764 - val_loss: 1.4456 - val_accuracy: 0.5260
# Epoch 5/50
# 110/111 [============================>.] - ETA: 0s - loss: 1.2272 - accuracy: 0.5739
# Epoch 5: val_loss improved from 1.44560 to 1.03996, saving model to Seed2/model-00005-1.22727-1.03996-.h5
# 111/111 [==============================] - 29s 246ms/step - loss: 1.2273 - accuracy: 0.5728 - val_loss: 1.0400 - val_accuracy: 0.6682
# Epoch 6/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.9645 - accuracy: 0.6679
# Epoch 6: val_loss improved from 1.03996 to 0.87318, saving model to Seed2/model-00006-0.96493-0.87318-.h5
# 111/111 [==============================] - 28s 244ms/step - loss: 0.9649 - accuracy: 0.6682 - val_loss: 0.8732 - val_accuracy: 0.7280
# Epoch 7/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.7911 - accuracy: 0.7261
# Epoch 7: val_loss improved from 0.87318 to 0.80700, saving model to Seed2/model-00007-0.78986-0.80700-.h5
# 111/111 [==============================] - 29s 247ms/step - loss: 0.7899 - accuracy: 0.7263 - val_loss: 0.8070 - val_accuracy: 0.7359
# Epoch 8/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.6825 - accuracy: 0.7662
# Epoch 8: val_loss improved from 0.80700 to 0.72101, saving model to Seed2/model-00008-0.68203-0.72101-.h5
# 111/111 [==============================] - 28s 243ms/step - loss: 0.6820 - accuracy: 0.7658 - val_loss: 0.7210 - val_accuracy: 0.7698
# Epoch 9/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.5695 - accuracy: 0.7966
# Epoch 9: val_loss did not improve from 0.72101
# 111/111 [==============================] - 28s 241ms/step - loss: 0.5707 - accuracy: 0.7954 - val_loss: 0.7595 - val_accuracy: 0.7686
# Epoch 10/50
# 111/111 [==============================] - ETA: 0s - loss: 0.4925 - accuracy: 0.8259
# Epoch 10: val_loss improved from 0.72101 to 0.68398, saving model to Seed2/model-00010-0.49251-0.68398-.h5
# 111/111 [==============================] - 28s 244ms/step - loss: 0.4925 - accuracy: 0.8259 - val_loss: 0.6840 - val_accuracy: 0.7935
# Epoch 11/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.4303 - accuracy: 0.8455
# Epoch 11: val_loss improved from 0.68398 to 0.67209, saving model to Seed2/model-00011-0.43018-0.67209-.h5
# 111/111 [==============================] - 28s 242ms/step - loss: 0.4302 - accuracy: 0.8459 - val_loss: 0.6721 - val_accuracy: 0.8115
# Epoch 12/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.3722 - accuracy: 0.8625
# Epoch 12: val_loss did not improve from 0.67209
# 111/111 [==============================] - 28s 240ms/step - loss: 0.3720 - accuracy: 0.8623 - val_loss: 0.7259 - val_accuracy: 0.7991
# Epoch 13/50
# 111/111 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.8764
# Epoch 13: val_loss improved from 0.67209 to 0.65821, saving model to Seed2/model-00013-0.32617-0.65821-.h5
# 111/111 [==============================] - 28s 238ms/step - loss: 0.3262 - accuracy: 0.8764 - val_loss: 0.6582 - val_accuracy: 0.8262
# Epoch 14/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.3134 - accuracy: 0.8872
# Epoch 14: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 237ms/step - loss: 0.3128 - accuracy: 0.8871 - val_loss: 0.8304 - val_accuracy: 0.7912
# Epoch 15/50
# 111/111 [==============================] - ETA: 0s - loss: 0.2417 - accuracy: 0.9072
# Epoch 15: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 239ms/step - loss: 0.2417 - accuracy: 0.9072 - val_loss: 0.7825 - val_accuracy: 0.8047
# Epoch 16/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.2135 - accuracy: 0.9213
# Epoch 16: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 239ms/step - loss: 0.2129 - accuracy: 0.9218 - val_loss: 0.8906 - val_accuracy: 0.7935
# Epoch 17/50
# 111/111 [==============================] - ETA: 0s - loss: 0.2397 - accuracy: 0.9176
# Epoch 17: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 238ms/step - loss: 0.2397 - accuracy: 0.9176 - val_loss: 0.9629 - val_accuracy: 0.7957
# Epoch 18/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.2397 - accuracy: 0.9125
# Epoch 18: val_loss did not improve from 0.65821
# 111/111 [==============================] - 33s 282ms/step - loss: 0.2384 - accuracy: 0.9131 - val_loss: 0.8351 - val_accuracy: 0.8104
# Epoch 19/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.1798 - accuracy: 0.9358
# Epoch 19: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 238ms/step - loss: 0.1818 - accuracy: 0.9354 - val_loss: 0.8895 - val_accuracy: 0.8205
# Epoch 20/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.1737 - accuracy: 0.9409
# Epoch 20: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 239ms/step - loss: 0.1733 - accuracy: 0.9410 - val_loss: 1.0165 - val_accuracy: 0.7901
# Epoch 21/50
# 111/111 [==============================] - ETA: 0s - loss: 0.1453 - accuracy: 0.9498
# Epoch 21: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 238ms/step - loss: 0.1453 - accuracy: 0.9498 - val_loss: 1.1966 - val_accuracy: 0.7777
# Epoch 22/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.2044 - accuracy: 0.9312
# Epoch 22: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 239ms/step - loss: 0.2040 - accuracy: 0.9314 - val_loss: 0.9087 - val_accuracy: 0.8115
# Epoch 23/50
# 111/111 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9512
# Epoch 23: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 240ms/step - loss: 0.1371 - accuracy: 0.9512 - val_loss: 0.9760 - val_accuracy: 0.8002
# Epoch 24/50
# 111/111 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9613
# Epoch 24: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 238ms/step - loss: 0.1165 - accuracy: 0.9613 - val_loss: 0.9806 - val_accuracy: 0.8025
# Epoch 25/50
# 110/111 [============================>.] - ETA: 0s - loss: 0.1140 - accuracy: 0.9602
# Epoch 25: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 239ms/step - loss: 0.1145 - accuracy: 0.9599 - val_loss: 0.9835 - val_accuracy: 0.8070
# Epoch 26/50
# 111/111 [==============================] - ETA: 0s - loss: 0.1022 - accuracy: 0.9647
# Epoch 26: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 239ms/step - loss: 0.1022 - accuracy: 0.9647 - val_loss: 1.0722 - val_accuracy: 0.8070
# Epoch 27/50
# 111/111 [==============================] - ETA: 0s - loss: 0.1066 - accuracy: 0.9628
# Epoch 27: val_loss did not improve from 0.65821
# 111/111 [==============================] - 32s 276ms/step - loss: 0.1066 - accuracy: 0.9628 - val_loss: 1.0321 - val_accuracy: 0.8284
# Epoch 28/50
# 111/111 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9664
# Epoch 28: val_loss did not improve from 0.65821
# 111/111 [==============================] - 28s 241ms/step - loss: 0.1000 - accuracy: 0.9664 - val_loss: 1.1325 - val_accuracy: 0.7844
# Epoch 28: early stopping

# %%
### visualizing the model results.
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(28)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Results from Model 2
# 1. The model is performing better than the previous model since there is comparatively less overfitting.
# 2. Training accuracy of 96% and validation accuracy of 78%.
# 3. Early Stopping used.
# 4. Validation loss improved from 2.25 to 1.13

# %% [markdown]
# ## Model 3
# #### Creating a model using data augmetation
# 1. layers.experimental.preprocessing.RandomFlip() - A preprocessing layer which randomly flips images during training.
# 2. layers.experimental.preprocessing.RandomRotation() - A preprocessing layer which randomly rotates images during training.

# %%
input_shape = (120,120,3)
num_classes = 12

model_aug = Sequential()
# scaling the images
model_aug.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, offset=0.0))
#layers.experimental.preprocessing.RandomFlip() - A preprocessing layer which randomly flips images during training.
#layers.experimental.preprocessing.RandomRotation() - A preprocessing layer which randomly rotates images during training.
model_aug.add(tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"))
model_aug.add(tf.keras.layers.experimental.preprocessing.RandomRotation(0.2))
model_aug.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same'))
model_aug.add(Activation('relu'))
model_aug.add(Conv2D(32, kernel_size=(3, 3)))
model_aug.add(Activation('relu'))
model_aug.add(MaxPooling2D(pool_size=(2, 2)))
# adding dropout layer after each Maxpooling layer
model_aug.add(Dropout(0.20))

model_aug.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model_aug.add(Activation('relu'))
model_aug.add(Conv2D(64, (3, 3)))
model_aug.add(Activation('relu'))
model_aug.add(MaxPooling2D(pool_size=(2, 2)))
model_aug.add(Dropout(0.20))

model_aug.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
model_aug.add(Activation('relu'))
model_aug.add(Conv2D(128, (3, 3)))
model_aug.add(Activation('relu'))
model_aug.add(MaxPooling2D(pool_size=(2, 2)))
model_aug.add(Dropout(0.20))

model_aug.add(Flatten())
model_aug.add(Dense(512))
model_aug.add(Activation('relu'))
model_aug.add(Dropout(0.20))
model_aug.add(Dense(num_classes))
model_aug.add(Activation('softmax'))

# %%
### compiling the augmented model
### choosing an appropirate optimiser and loss function

opt = Adam(0.001)
model_aug.compile(optimizer=opt,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# spefying the format in which model needs to be saved
model_name = 'Seed3' + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)
 # giving the file path
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{val_loss:.5f}-.h5'
# Creating the call back for saving only the best models
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
# creating the callback for early stopping
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)

callbacks_list = [checkpoint, early_stopping]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
### training the model
epochs = 100
batch_size = 32
history = model_aug.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size, callbacks=callbacks_list, shuffle=True)
# Out:
# Epoch 1/100
# 111/111 [==============================] - ETA: 0s - loss: 2.4280 - accuracy: 0.1462
# Epoch 1: val_loss improved from inf to 2.36846, saving model to Seed3/model-00001-2.42802-2.36846-.h5
# 111/111 [==============================] - 33s 242ms/step - loss: 2.4280 - accuracy: 0.1462 - val_loss: 2.3685 - val_accuracy: 0.2540
# Epoch 2/100
# 110/111 [============================>.] - ETA: 0s - loss: 1.7922 - accuracy: 0.3676
# Epoch 2: val_loss improved from 2.36846 to 1.46164, saving model to Seed3/model-00002-1.79036-1.46164-.h5
# 111/111 [==============================] - 31s 266ms/step - loss: 1.7904 - accuracy: 0.3674 - val_loss: 1.4616 - val_accuracy: 0.4797
# Epoch 3/100
# 110/111 [============================>.] - ETA: 0s - loss: 1.3922 - accuracy: 0.5082
# Epoch 3: val_loss improved from 1.46164 to 1.10856, saving model to Seed3/model-00003-1.38799-1.10856-.h5
# 111/111 [==============================] - 29s 250ms/step - loss: 1.3880 - accuracy: 0.5096 - val_loss: 1.1086 - val_accuracy: 0.6411
# Epoch 4/100
# 110/111 [============================>.] - ETA: 0s - loss: 1.1360 - accuracy: 0.6017
# Epoch 4: val_loss improved from 1.10856 to 0.95798, saving model to Seed3/model-00004-1.13372-0.95798-.h5
# 111/111 [==============================] - 30s 257ms/step - loss: 1.1337 - accuracy: 0.6027 - val_loss: 0.9580 - val_accuracy: 0.6783
# Epoch 5/100
# 110/111 [============================>.] - ETA: 0s - loss: 1.0101 - accuracy: 0.6557
# Epoch 5: val_loss did not improve from 0.95798
# 111/111 [==============================] - 28s 242ms/step - loss: 1.0080 - accuracy: 0.6566 - val_loss: 1.0724 - val_accuracy: 0.6637
# Epoch 6/100
# 111/111 [==============================] - ETA: 0s - loss: 0.9467 - accuracy: 0.6789
# Epoch 6: val_loss improved from 0.95798 to 0.79476, saving model to Seed3/model-00006-0.94669-0.79476-.h5
# 111/111 [==============================] - 28s 244ms/step - loss: 0.9467 - accuracy: 0.6789 - val_loss: 0.7948 - val_accuracy: 0.7472
# Epoch 7/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.8741 - accuracy: 0.7048
# Epoch 7: val_loss did not improve from 0.79476
# 111/111 [==============================] - 28s 241ms/step - loss: 0.8738 - accuracy: 0.7051 - val_loss: 0.8083 - val_accuracy: 0.7460
# Epoch 8/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.8420 - accuracy: 0.7131
# Epoch 8: val_loss improved from 0.79476 to 0.71307, saving model to Seed3/model-00008-0.84121-0.71307-.h5
# 111/111 [==============================] - 28s 245ms/step - loss: 0.8412 - accuracy: 0.7136 - val_loss: 0.7131 - val_accuracy: 0.7799
# Epoch 9/100
# 111/111 [==============================] - ETA: 0s - loss: 0.7784 - accuracy: 0.7381
# Epoch 9: val_loss improved from 0.71307 to 0.63082, saving model to Seed3/model-00009-0.77837-0.63082-.h5
# 111/111 [==============================] - 29s 246ms/step - loss: 0.7784 - accuracy: 0.7381 - val_loss: 0.6308 - val_accuracy: 0.7957
# Epoch 10/100
# 111/111 [==============================] - ETA: 0s - loss: 0.7365 - accuracy: 0.7463
# Epoch 10: val_loss did not improve from 0.63082
# 111/111 [==============================] - 29s 246ms/step - loss: 0.7365 - accuracy: 0.7463 - val_loss: 0.7142 - val_accuracy: 0.7777
# Epoch 11/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.7134 - accuracy: 0.7503
# Epoch 11: val_loss improved from 0.63082 to 0.61951, saving model to Seed3/model-00011-0.71224-0.61951-.h5
# 111/111 [==============================] - 29s 244ms/step - loss: 0.7122 - accuracy: 0.7506 - val_loss: 0.6195 - val_accuracy: 0.7980
# Epoch 12/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.6759 - accuracy: 0.7662
# Epoch 12: val_loss improved from 0.61951 to 0.54931, saving model to Seed3/model-00012-0.67416-0.54931-.h5
# 111/111 [==============================] - 29s 240ms/step - loss: 0.6742 - accuracy: 0.7666 - val_loss: 0.5493 - val_accuracy: 0.8307
# Epoch 13/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.6008 - accuracy: 0.7912
# Epoch 13: val_loss improved from 0.54931 to 0.51369, saving model to Seed3/model-00013-0.60000-0.51369-.h5
# 111/111 [==============================] - 28s 237ms/step - loss: 0.6000 - accuracy: 0.7918 - val_loss: 0.5137 - val_accuracy: 0.8397
# Epoch 14/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.5811 - accuracy: 0.8009
# Epoch 14: val_loss improved from 0.51369 to 0.48402, saving model to Seed3/model-00014-0.58165-0.48402-.h5
# 111/111 [==============================] - 29s 237ms/step - loss: 0.5817 - accuracy: 0.8008 - val_loss: 0.4840 - val_accuracy: 0.8578
# Epoch 15/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.5599 - accuracy: 0.8071
# Epoch 15: val_loss did not improve from 0.48402
# 111/111 [==============================] - 28s 231ms/step - loss: 0.5597 - accuracy: 0.8070 - val_loss: 0.4840 - val_accuracy: 0.8420
# Epoch 16/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.5141 - accuracy: 0.8193
# Epoch 16: val_loss improved from 0.48402 to 0.45737, saving model to Seed3/model-00016-0.51522-0.45737-.h5
# 111/111 [==============================] - 29s 238ms/step - loss: 0.5152 - accuracy: 0.8194 - val_loss: 0.4574 - val_accuracy: 0.8567
# Epoch 17/100
# 111/111 [==============================] - ETA: 0s - loss: 0.5014 - accuracy: 0.8231
# Epoch 17: val_loss improved from 0.45737 to 0.44480, saving model to Seed3/model-00017-0.50140-0.44480-.h5
# 111/111 [==============================] - 29s 238ms/step - loss: 0.5014 - accuracy: 0.8231 - val_loss: 0.4448 - val_accuracy: 0.8521
# Epoch 18/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4809 - accuracy: 0.8307
# Epoch 18: val_loss improved from 0.44480 to 0.39206, saving model to Seed3/model-00018-0.48087-0.39206-.h5
# 111/111 [==============================] - 29s 238ms/step - loss: 0.4809 - accuracy: 0.8307 - val_loss: 0.3921 - val_accuracy: 0.8725
# Epoch 19/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4495 - accuracy: 0.8392
# Epoch 19: val_loss did not improve from 0.39206
# 111/111 [==============================] - 28s 231ms/step - loss: 0.4495 - accuracy: 0.8392 - val_loss: 0.4223 - val_accuracy: 0.8612
# Epoch 20/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.4126 - accuracy: 0.8511
# Epoch 20: val_loss did not improve from 0.39206
# 111/111 [==============================] - 28s 231ms/step - loss: 0.4124 - accuracy: 0.8510 - val_loss: 0.4120 - val_accuracy: 0.8533
# Epoch 21/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.4265 - accuracy: 0.8418
# Epoch 21: val_loss did not improve from 0.39206
# 111/111 [==============================] - 28s 228ms/step - loss: 0.4256 - accuracy: 0.8420 - val_loss: 0.4513 - val_accuracy: 0.8555
# Epoch 22/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4051 - accuracy: 0.8485
# Epoch 22: val_loss improved from 0.39206 to 0.35239, saving model to Seed3/model-00022-0.40512-0.35239-.h5
# 111/111 [==============================] - 28s 234ms/step - loss: 0.4051 - accuracy: 0.8485 - val_loss: 0.3524 - val_accuracy: 0.8804
# Epoch 23/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.4091 - accuracy: 0.8497
# Epoch 23: val_loss did not improve from 0.35239
# 111/111 [==============================] - 28s 229ms/step - loss: 0.4083 - accuracy: 0.8499 - val_loss: 0.3809 - val_accuracy: 0.8837
# Epoch 24/100
# 111/111 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 0.8578
# Epoch 24: val_loss did not improve from 0.35239
# 111/111 [==============================] - 28s 231ms/step - loss: 0.4136 - accuracy: 0.8578 - val_loss: 0.3924 - val_accuracy: 0.8713
# Epoch 25/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.3649 - accuracy: 0.8690
# Epoch 25: val_loss improved from 0.35239 to 0.34415, saving model to Seed3/model-00025-0.36480-0.34415-.h5
# 111/111 [==============================] - 34s 283ms/step - loss: 0.3648 - accuracy: 0.8685 - val_loss: 0.3442 - val_accuracy: 0.8736
# Epoch 26/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.3773 - accuracy: 0.8642
# Epoch 26: val_loss improved from 0.34415 to 0.34049, saving model to Seed3/model-00026-0.37729-0.34049-.h5
# 111/111 [==============================] - 33s 283ms/step - loss: 0.3773 - accuracy: 0.8643 - val_loss: 0.3405 - val_accuracy: 0.8837
# Epoch 27/100
# 111/111 [==============================] - ETA: 0s - loss: 0.3619 - accuracy: 0.8705
# Epoch 27: val_loss did not improve from 0.34049
# 111/111 [==============================] - 28s 242ms/step - loss: 0.3619 - accuracy: 0.8705 - val_loss: 0.3533 - val_accuracy: 0.8713
# Epoch 28/100
# 111/111 [==============================] - ETA: 0s - loss: 0.3591 - accuracy: 0.8685
# Epoch 28: val_loss improved from 0.34049 to 0.30785, saving model to Seed3/model-00028-0.35912-0.30785-.h5
# 111/111 [==============================] - 28s 243ms/step - loss: 0.3591 - accuracy: 0.8685 - val_loss: 0.3078 - val_accuracy: 0.9007
# Epoch 29/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.3133 - accuracy: 0.8838
# Epoch 29: val_loss did not improve from 0.30785
# 111/111 [==============================] - 28s 239ms/step - loss: 0.3129 - accuracy: 0.8840 - val_loss: 0.3826 - val_accuracy: 0.8510
# Epoch 30/100
# 111/111 [==============================] - ETA: 0s - loss: 0.3239 - accuracy: 0.8775
# Epoch 30: val_loss did not improve from 0.30785
# 111/111 [==============================] - 28s 240ms/step - loss: 0.3239 - accuracy: 0.8775 - val_loss: 0.3797 - val_accuracy: 0.8679
# Epoch 31/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.3355 - accuracy: 0.8713
# Epoch 31: val_loss did not improve from 0.30785
# 111/111 [==============================] - 28s 239ms/step - loss: 0.3345 - accuracy: 0.8716 - val_loss: 0.3208 - val_accuracy: 0.8939
# Epoch 32/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2999 - accuracy: 0.8881
# Epoch 32: val_loss did not improve from 0.30785
# 111/111 [==============================] - 28s 241ms/step - loss: 0.2996 - accuracy: 0.8883 - val_loss: 0.3713 - val_accuracy: 0.8781
# Epoch 33/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8902
# Epoch 33: val_loss did not improve from 0.30785
# 111/111 [==============================] - 28s 241ms/step - loss: 0.2921 - accuracy: 0.8902 - val_loss: 0.3341 - val_accuracy: 0.8849
# Epoch 34/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.3025 - accuracy: 0.8875
# Epoch 34: val_loss did not improve from 0.30785
# 111/111 [==============================] - 28s 240ms/step - loss: 0.3018 - accuracy: 0.8880 - val_loss: 0.3275 - val_accuracy: 0.8962
# Epoch 35/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2909 - accuracy: 0.8878
# Epoch 35: val_loss did not improve from 0.30785
# 111/111 [==============================] - 28s 242ms/step - loss: 0.2899 - accuracy: 0.8885 - val_loss: 0.3097 - val_accuracy: 0.8973
# Epoch 36/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2948 - accuracy: 0.8878
# Epoch 36: val_loss did not improve from 0.30785
# 111/111 [==============================] - 28s 240ms/step - loss: 0.2949 - accuracy: 0.8877 - val_loss: 0.3746 - val_accuracy: 0.8758
# Epoch 37/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.3016 - accuracy: 0.8838
# Epoch 37: val_loss improved from 0.30785 to 0.29984, saving model to Seed3/model-00037-0.30177-0.29984-.h5
# 111/111 [==============================] - 28s 243ms/step - loss: 0.3018 - accuracy: 0.8835 - val_loss: 0.2998 - val_accuracy: 0.8950
# Epoch 38/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2977 - accuracy: 0.8884
# Epoch 38: val_loss improved from 0.29984 to 0.29767, saving model to Seed3/model-00038-0.29964-0.29767-.h5
# 111/111 [==============================] - 29s 250ms/step - loss: 0.2996 - accuracy: 0.8877 - val_loss: 0.2977 - val_accuracy: 0.8984
# Epoch 39/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2667 - accuracy: 0.8993
# Epoch 39: val_loss did not improve from 0.29767
# 111/111 [==============================] - 28s 242ms/step - loss: 0.2667 - accuracy: 0.8993 - val_loss: 0.3733 - val_accuracy: 0.8860
# Epoch 40/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.8922
# Epoch 40: val_loss did not improve from 0.29767
# 111/111 [==============================] - 34s 292ms/step - loss: 0.2739 - accuracy: 0.8922 - val_loss: 0.3045 - val_accuracy: 0.9063
# Epoch 41/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2770 - accuracy: 0.8946
# Epoch 41: val_loss did not improve from 0.29767
# 111/111 [==============================] - 29s 238ms/step - loss: 0.2767 - accuracy: 0.8945 - val_loss: 0.3164 - val_accuracy: 0.8950
# Epoch 42/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2793 - accuracy: 0.8964
# Epoch 42: val_loss did not improve from 0.29767
# 111/111 [==============================] - 28s 232ms/step - loss: 0.2793 - accuracy: 0.8964 - val_loss: 0.3235 - val_accuracy: 0.8939
# Epoch 43/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.8995
# Epoch 43: val_loss did not improve from 0.29767
# 111/111 [==============================] - 28s 232ms/step - loss: 0.2641 - accuracy: 0.8995 - val_loss: 0.3064 - val_accuracy: 0.9029
# Epoch 44/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2660 - accuracy: 0.8986
# Epoch 44: val_loss did not improve from 0.29767
# 111/111 [==============================] - 28s 234ms/step - loss: 0.2657 - accuracy: 0.8987 - val_loss: 0.3161 - val_accuracy: 0.9052
# Epoch 45/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2472 - accuracy: 0.9043
# Epoch 45: val_loss did not improve from 0.29767
# 111/111 [==============================] - 28s 234ms/step - loss: 0.2476 - accuracy: 0.9041 - val_loss: 0.3081 - val_accuracy: 0.8950
# Epoch 46/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9128
# Epoch 46: val_loss did not improve from 0.29767
# 111/111 [==============================] - 28s 235ms/step - loss: 0.2308 - accuracy: 0.9128 - val_loss: 0.3109 - val_accuracy: 0.8928
# Epoch 47/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9136
# Epoch 47: val_loss did not improve from 0.29767
# 111/111 [==============================] - 28s 236ms/step - loss: 0.2214 - accuracy: 0.9142 - val_loss: 0.3244 - val_accuracy: 0.9108
# Epoch 48/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9094
# Epoch 48: val_loss improved from 0.29767 to 0.29361, saving model to Seed3/model-00048-0.24088-0.29361-.h5
# 111/111 [==============================] - 29s 239ms/step - loss: 0.2409 - accuracy: 0.9094 - val_loss: 0.2936 - val_accuracy: 0.9097
# Epoch 49/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2513 - accuracy: 0.9131
# Epoch 49: val_loss improved from 0.29361 to 0.27954, saving model to Seed3/model-00049-0.25134-0.27954-.h5
# 111/111 [==============================] - 29s 236ms/step - loss: 0.2513 - accuracy: 0.9131 - val_loss: 0.2795 - val_accuracy: 0.9244
# Epoch 50/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2394 - accuracy: 0.9091
# Epoch 50: val_loss improved from 0.27954 to 0.26166, saving model to Seed3/model-00050-0.23987-0.26166-.h5
# 111/111 [==============================] - 29s 241ms/step - loss: 0.2399 - accuracy: 0.9086 - val_loss: 0.2617 - val_accuracy: 0.9176
# Epoch 51/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.9106
# Epoch 51: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 227ms/step - loss: 0.2367 - accuracy: 0.9106 - val_loss: 0.3441 - val_accuracy: 0.8995
# Epoch 52/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2355 - accuracy: 0.9105
# Epoch 52: val_loss did not improve from 0.26166
# 111/111 [==============================] - 29s 237ms/step - loss: 0.2349 - accuracy: 0.9108 - val_loss: 0.2867 - val_accuracy: 0.9165
# Epoch 53/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2377 - accuracy: 0.9083
# Epoch 53: val_loss did not improve from 0.26166
# 111/111 [==============================] - 33s 280ms/step - loss: 0.2377 - accuracy: 0.9083 - val_loss: 0.2836 - val_accuracy: 0.9052
# Epoch 54/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2065 - accuracy: 0.9170
# Epoch 54: val_loss did not improve from 0.26166
# 111/111 [==============================] - 33s 280ms/step - loss: 0.2058 - accuracy: 0.9176 - val_loss: 0.3146 - val_accuracy: 0.9029
# Epoch 55/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.1991 - accuracy: 0.9236
# Epoch 55: val_loss did not improve from 0.26166
# 111/111 [==============================] - 33s 280ms/step - loss: 0.1986 - accuracy: 0.9238 - val_loss: 0.3399 - val_accuracy: 0.8973
# Epoch 56/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2215 - accuracy: 0.9139
# Epoch 56: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 241ms/step - loss: 0.2223 - accuracy: 0.9139 - val_loss: 0.2943 - val_accuracy: 0.9176
# Epoch 57/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2149 - accuracy: 0.9190
# Epoch 57: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 238ms/step - loss: 0.2174 - accuracy: 0.9185 - val_loss: 0.2858 - val_accuracy: 0.9142
# Epoch 58/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2274 - accuracy: 0.9190
# Epoch 58: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 239ms/step - loss: 0.2274 - accuracy: 0.9190 - val_loss: 0.3218 - val_accuracy: 0.8883
# Epoch 59/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2315 - accuracy: 0.9131
# Epoch 59: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 239ms/step - loss: 0.2311 - accuracy: 0.9131 - val_loss: 0.2902 - val_accuracy: 0.9210
# Epoch 60/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2421 - accuracy: 0.9111
# Epoch 60: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 241ms/step - loss: 0.2421 - accuracy: 0.9111 - val_loss: 0.2979 - val_accuracy: 0.9097
# Epoch 61/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2180 - accuracy: 0.9182
# Epoch 61: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 243ms/step - loss: 0.2180 - accuracy: 0.9182 - val_loss: 0.2973 - val_accuracy: 0.9120
# Epoch 62/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2160 - accuracy: 0.9253
# Epoch 62: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 242ms/step - loss: 0.2159 - accuracy: 0.9255 - val_loss: 0.3731 - val_accuracy: 0.8804
# Epoch 63/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2283 - accuracy: 0.9077
# Epoch 63: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 241ms/step - loss: 0.2291 - accuracy: 0.9077 - val_loss: 0.2737 - val_accuracy: 0.9289
# Epoch 64/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2020 - accuracy: 0.9213
# Epoch 64: val_loss did not improve from 0.26166
# 111/111 [==============================] - 28s 243ms/step - loss: 0.2017 - accuracy: 0.9213 - val_loss: 0.2779 - val_accuracy: 0.9255
# Epoch 65/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2086 - accuracy: 0.9213
# Epoch 65: val_loss improved from 0.26166 to 0.26095, saving model to Seed3/model-00065-0.20764-0.26095-.h5
# 111/111 [==============================] - 28s 244ms/step - loss: 0.2076 - accuracy: 0.9218 - val_loss: 0.2610 - val_accuracy: 0.9278
# Epoch 66/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.1828 - accuracy: 0.9278
# Epoch 66: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 242ms/step - loss: 0.1832 - accuracy: 0.9272 - val_loss: 0.2997 - val_accuracy: 0.9221
# Epoch 67/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2154 - accuracy: 0.9280
# Epoch 67: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 240ms/step - loss: 0.2154 - accuracy: 0.9280 - val_loss: 0.3020 - val_accuracy: 0.9131
# Epoch 68/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.1745 - accuracy: 0.9276
# Epoch 68: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 239ms/step - loss: 0.1758 - accuracy: 0.9266 - val_loss: 0.3112 - val_accuracy: 0.9041
# Epoch 69/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2138 - accuracy: 0.9222
# Epoch 69: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 240ms/step - loss: 0.2136 - accuracy: 0.9221 - val_loss: 0.3187 - val_accuracy: 0.9165
# Epoch 70/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.1934 - accuracy: 0.9287
# Epoch 70: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 242ms/step - loss: 0.1949 - accuracy: 0.9283 - val_loss: 0.2892 - val_accuracy: 0.9221
# Epoch 71/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2033 - accuracy: 0.9218
# Epoch 71: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 241ms/step - loss: 0.2033 - accuracy: 0.9218 - val_loss: 0.3151 - val_accuracy: 0.8883
# Epoch 72/100
# 111/111 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9306
# Epoch 72: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 239ms/step - loss: 0.1871 - accuracy: 0.9306 - val_loss: 0.3908 - val_accuracy: 0.8928
# Epoch 73/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.2043 - accuracy: 0.9230
# Epoch 73: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 238ms/step - loss: 0.2032 - accuracy: 0.9235 - val_loss: 0.2942 - val_accuracy: 0.9278
# Epoch 74/100
# 111/111 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9289
# Epoch 74: val_loss did not improve from 0.26095
# 111/111 [==============================] - 33s 286ms/step - loss: 0.1753 - accuracy: 0.9289 - val_loss: 0.2854 - val_accuracy: 0.9255
# Epoch 75/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9222
# Epoch 75: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 238ms/step - loss: 0.1978 - accuracy: 0.9224 - val_loss: 0.2956 - val_accuracy: 0.9289
# Epoch 76/100
# 111/111 [==============================] - ETA: 0s - loss: 0.2010 - accuracy: 0.9238
# Epoch 76: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 240ms/step - loss: 0.2010 - accuracy: 0.9238 - val_loss: 0.2667 - val_accuracy: 0.9244
# Epoch 77/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.1849 - accuracy: 0.9264
# Epoch 77: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 242ms/step - loss: 0.1857 - accuracy: 0.9261 - val_loss: 0.3235 - val_accuracy: 0.9187
# Epoch 78/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.1801 - accuracy: 0.9310
# Epoch 78: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 239ms/step - loss: 0.1791 - accuracy: 0.9314 - val_loss: 0.2686 - val_accuracy: 0.9233
# Epoch 79/100
# 111/111 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9266
# Epoch 79: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 240ms/step - loss: 0.1883 - accuracy: 0.9266 - val_loss: 0.2808 - val_accuracy: 0.9086
# Epoch 80/100
# 110/111 [============================>.] - ETA: 0s - loss: 0.1586 - accuracy: 0.9426
# Epoch 80: val_loss did not improve from 0.26095
# 111/111 [==============================] - 28s 240ms/step - loss: 0.1580 - accuracy: 0.9427 - val_loss: 0.2971 - val_accuracy: 0.9187
# Epoch 80: early stopping

# %%
### visualizing the model results.
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(80)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Results from Model 3
# 1. Including Data Augmentation has improved the model accuracy to 94% and also handled overfitting to great extent.
# 2. Data Augmentation has improved the model performance.
# 3. Validation loss have improved from 1.13 to 0.29

# %% [markdown]
# ## Model 4
#
# Context: Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
### defining the path for training and test images
train_path = "/content/dataset/train/"
test_path = "/content/dataset/test/"

# %%
### distibution of classes for each category of data
### It can be seen that data has imbalances in the class distribution
for i in labels:
    directory =train_path + i + '/'
    class_directory = pathlib.Path(directory)
    length=len(list(class_directory.glob('*.png')))
    print(f'{i} has {length} samples.')
# Out:
# Black-grass has 247 samples.
# Charlock has 361 samples.
# Cleavers has 268 samples.
# Common Chickweed has 570 samples.
# Common wheat has 202 samples.
# Fat Hen has 430 samples.
# Loose Silky-bent has 613 samples.
# Maize has 205 samples.
# Scentless Mayweed has 485 samples.
# Shepherd’s Purse has 219 samples.
# Small-flowered Cranesbill has 460 samples.
# Sugar beet has 370 samples.

# %%
# You can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes
# so that none of the classes have very few samples.
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.22.4)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use Augmentor, the following general procedure is followed:
#
# 1. Instantiate a Pipeline object pointing to a directory containing your initial image data set.
# 2. Define a number of operations to perform on this data set using your Pipeline object.
# 3. Execute these operations by calling the Pipeline’s sample() method.

# %%
path_to_training_dataset=train_path

import Augmentor
for i in labels:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 247 image(s) found.
# Output directory set to /content/dataset/train/Black-grass/output.
# Processing <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1109x1109 at 0x7EB7B441BA60>: 100%|██████████| 500/500 [02:22<00:00,  3.50 Samples/s]
# Initialised with 361 image(s) found.
# Output directory set to /content/dataset/train/Charlock/output.
# Processing <PIL.PngImagePlugin.PngImageFile image mode=RGB size=730x730 at 0x7EB7C6EDF640>: 100%|██████████| 500/500 [01:06<00:00,  7.48 Samples/s]
# Initialised with 268 image(s) found.
# Output directory set to /content/dataset/train/Cleavers/output.
# Processing <PIL.Image.Image image mode=RGB size=190x190 at 0x7EB7DC0B1690>: 100%|██████████| 500/500 [00:27<00:00, 18.07 Samples/s]
# Initialised with 570 image(s) found.
# Output directory set to /content/dataset/train/Common Chickweed/output.
# Processing <PIL.Image.Image image mode=RGB size=411x411 at 0x7EB81B9661D0>: 100%|██████████| 500/500 [00:20<00:00, 23.96 Samples/s]
# Initialised with 202 image(s) found.
# Output directory set to /content/dataset/train/Common wheat/output.
# Processing <PIL.PngImagePlugin.PngImageFile image mode=RGB size=556x556 at 0x7EB7EE3578B0>: 100%|██████████| 500/500 [01:05<00:00,  7.59 Samples/s]
# Initialised with 430 image(s) found.
# Output directory set to /content/dataset/train/Fat Hen/output.
# Processing <PIL.Image.Image image mode=RGB size=431x431 at 0x7EB8502F3790>: 100%|██████████| 500/500 [00:32<00:00, 15.56 Samples/s]
# Initialised with 613 image(s) found.
# Output directory set to /content/dataset/train/Loose Silky-bent/output.
# Processing <PIL.Image.Image image mode=RGB size=1943x1942 at 0x7EB8FA793E50>: 100%|██████████| 500/500 [01:02<00:00,  7.95 Samples/s]
# Initialised with 205 image(s) found.
# Output directory set to /content/dataset/train/Maize/output.
# Processing <PIL.Image.Image image mode=RGB size=852x852 at 0x7EB7CE0B13F0>: 100%|██████████| 500/500 [01:31<00:00,  5.48 Samples/s]
# Initialised with 485 image(s) found.
# Output directory set to /content/dataset/train/Scentless Mayweed/output.
# Processing <PIL.PngImagePlugin.PngImageFile image mode=RGB size=58x58 at 0x7EB85FD8E710>: 100%|██████████| 500/500 [00:22<00:00, 22.36 Samples/s]
# Initialised with 219 image(s) found.
# Output directory set to /content/dataset/train/Shepherd’s Purse/output.
# Processing <PIL.Image.Image image mode=RGB size=925x925 at 0x7EB7B8C8AD40>: 100%|██████████| 500/500 [00:37<00:00, 13.17 Samples/s]
# Initialised with 460 image(s) found.
# Output directory set to /content/dataset/train/Small-flowered Cranesbill/output.
# Processing <PIL.Image.Image image mode=RGB size=116x116 at 0x7EB85FD38100>: 100%|██████████| 500/500 [00:36<00:00, 13.59 Samples/s]
# Initialised with 370 image(s) found.
# Output directory set to /content/dataset/train/Sugar beet/output.
# Processing <PIL.Image.Image image mode=RGB size=1036x1036 at 0x7EB7CF4A7EB0>: 100%|██████████| 500/500 [01:54<00:00,  4.37 Samples/s]

# %%
### Distribution of classes after augmentation
for i in labels:
    directory =train_path+i+'/'
    directory_out =train_path+i+'/output/'
    class_directory = pathlib.Path(directory)
    class_directory_out = pathlib.Path(directory_out)
    length=len(list(class_directory.glob('*.png')))
    length_out=len(list(class_directory_out.glob('*.png')))
    length_tot=length+length_out
    print(f'{i} has {length_tot} samples.')
# Out:
# Black-grass has 747 samples.
# Charlock has 861 samples.
# Cleavers has 768 samples.
# Common Chickweed has 1070 samples.
# Common wheat has 702 samples.
# Fat Hen has 930 samples.
# Loose Silky-bent has 1113 samples.
# Maize has 705 samples.
# Scentless Mayweed has 985 samples.
# Shepherd’s Purse has 719 samples.
# Small-flowered Cranesbill has 960 samples.
# Sugar beet has 870 samples.

# %%
batch_size = 32
img_height = 120
img_width = 120

# %%
data_dir_train=train_path
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123, label_mode='categorical',
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 10430 files belonging to 12 classes.
# Using 8344 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123, label_mode='categorical',
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 10430 files belonging to 12 classes.
# Using 2086 files for validation.

# %%
input_shape = (120,120,3)
num_classes = 12

model4 = Sequential()
model4.add(tf.keras.layers.experimental.preprocessing.Rescaling(1./255, offset=0.0))
model4.add(Conv2D(32, kernel_size=(3, 3), input_shape=input_shape, padding='same'))
model4.add(Activation('relu'))
model4.add(Conv2D(32, kernel_size=(3, 3)))
model4.add(Activation('relu'))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.10))

model4.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model4.add(Activation('relu'))
model4.add(Conv2D(64, (3, 3)))
model4.add(Activation('relu'))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.10))

model4.add(Conv2D(128, kernel_size=(3, 3), padding='same'))
model4.add(Activation('relu'))
model4.add(Conv2D(128, (3, 3)))
model4.add(Activation('relu'))
model4.add(MaxPooling2D(pool_size=(2, 2)))
model4.add(Dropout(0.10))

model4.add(Flatten())
model4.add(Dense(256))
model4.add(Activation('relu'))
model4.add(Dropout(0.25))
model4.add(Dense(num_classes))
model4.add(Activation('softmax'))

# %%
### choosing an appropirate optimiser and loss function
model4.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# spefying the format in which model needs to be saved
model_name = 'Seed4' + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)
 # giving the file path
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{val_loss:.5f}-.h5'
# Creating the call back for saving only the best models
lr_reduce = ReduceLROnPlateau(monitor='val_accuracy', factor=0.6, patience=5, verbose=1, mode='max', min_lr=1e-5)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
# creating the callback for early stopping
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

callbacks_list = [checkpoint, early_stopping, lr_reduce]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
### training the model
epochs = 100
batch_size = 32
history = model4.fit(train_ds, validation_data=val_ds, epochs=epochs, batch_size=batch_size, callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 260/261 [============================>.] - ETA: 0s - loss: 1.9083 - accuracy: 0.3125
# Epoch 1: val_loss improved from inf to 1.29357, saving model to Seed4/model-00001-1.90669-1.29357-.h5
# 261/261 [==============================] - 85s 307ms/step - loss: 1.9067 - accuracy: 0.3132 - val_loss: 1.2936 - val_accuracy: 0.5211 - lr: 0.0010
# Epoch 2/100
# 260/261 [============================>.] - ETA: 0s - loss: 1.0963 - accuracy: 0.5990
# Epoch 2: val_loss improved from 1.29357 to 0.92870, saving model to Seed4/model-00002-1.09647-0.92870-.h5
# 261/261 [==============================] - 78s 295ms/step - loss: 1.0965 - accuracy: 0.5992 - val_loss: 0.9287 - val_accuracy: 0.6692 - lr: 0.0010
# Epoch 3/100
# 261/261 [==============================] - ETA: 0s - loss: 0.7103 - accuracy: 0.7366
# Epoch 3: val_loss improved from 0.92870 to 0.64825, saving model to Seed4/model-00003-0.71028-0.64825-.h5
# 261/261 [==============================] - 79s 298ms/step - loss: 0.7103 - accuracy: 0.7366 - val_loss: 0.6482 - val_accuracy: 0.7584 - lr: 0.0010
# Epoch 4/100
# 261/261 [==============================] - ETA: 0s - loss: 0.5088 - accuracy: 0.8145
# Epoch 4: val_loss improved from 0.64825 to 0.42681, saving model to Seed4/model-00004-0.50878-0.42681-.h5
# 261/261 [==============================] - 78s 294ms/step - loss: 0.5088 - accuracy: 0.8145 - val_loss: 0.4268 - val_accuracy: 0.8514 - lr: 0.0010
# Epoch 5/100
# 260/261 [============================>.] - ETA: 0s - loss: 0.3848 - accuracy: 0.8587
# Epoch 5: val_loss did not improve from 0.42681
# 261/261 [==============================] - 80s 300ms/step - loss: 0.3850 - accuracy: 0.8587 - val_loss: 0.5325 - val_accuracy: 0.8447 - lr: 0.0010
# Epoch 6/100
# 260/261 [============================>.] - ETA: 0s - loss: 0.3064 - accuracy: 0.8904
# Epoch 6: val_loss improved from 0.42681 to 0.39937, saving model to Seed4/model-00006-0.30629-0.39937-.h5
# 261/261 [==============================] - 81s 302ms/step - loss: 0.3063 - accuracy: 0.8905 - val_loss: 0.3994 - val_accuracy: 0.8778 - lr: 0.0010
# Epoch 7/100
# 260/261 [============================>.] - ETA: 0s - loss: 0.2368 - accuracy: 0.9175
# Epoch 7: val_loss improved from 0.39937 to 0.35858, saving model to Seed4/model-00007-0.23701-0.35858-.h5
# 261/261 [==============================] - 87s 326ms/step - loss: 0.2370 - accuracy: 0.9177 - val_loss: 0.3586 - val_accuracy: 0.8907 - lr: 0.0010
# Epoch 8/100
# 261/261 [==============================] - ETA: 0s - loss: 0.2015 - accuracy: 0.9295
# Epoch 8: val_loss improved from 0.35858 to 0.35358, saving model to Seed4/model-00008-0.20146-0.35358-.h5
# 261/261 [==============================] - 80s 302ms/step - loss: 0.2015 - accuracy: 0.9295 - val_loss: 0.3536 - val_accuracy: 0.8945 - lr: 0.0010
# Epoch 9/100
# 260/261 [============================>.] - ETA: 0s - loss: 0.1819 - accuracy: 0.9382
# Epoch 9: val_loss improved from 0.35358 to 0.30653, saving model to Seed4/model-00009-0.18147-0.30653-.h5
# 261/261 [==============================] - 79s 296ms/step - loss: 0.1815 - accuracy: 0.9384 - val_loss: 0.3065 - val_accuracy: 0.9175 - lr: 0.0010
# Epoch 10/100
# 261/261 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9521
# Epoch 10: val_loss did not improve from 0.30653
# 261/261 [==============================] - 80s 300ms/step - loss: 0.1482 - accuracy: 0.9521 - val_loss: 0.3415 - val_accuracy: 0.9046 - lr: 0.0010
# Epoch 11/100
# 261/261 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9510
# Epoch 11: val_loss did not improve from 0.30653
# 261/261 [==============================] - 85s 319ms/step - loss: 0.1444 - accuracy: 0.9510 - val_loss: 0.3082 - val_accuracy: 0.9166 - lr: 0.0010
# Epoch 12/100
# 261/261 [==============================] - ETA: 0s - loss: 0.1085 - accuracy: 0.9668
# Epoch 12: val_loss did not improve from 0.30653
# 261/261 [==============================] - 85s 322ms/step - loss: 0.1085 - accuracy: 0.9668 - val_loss: 0.3621 - val_accuracy: 0.9171 - lr: 0.0010
# Epoch 13/100
# 261/261 [==============================] - ETA: 0s - loss: 0.0886 - accuracy: 0.9693
# Epoch 13: val_loss did not improve from 0.30653
# 261/261 [==============================] - 80s 301ms/step - loss: 0.0886 - accuracy: 0.9693 - val_loss: 0.3293 - val_accuracy: 0.9228 - lr: 0.0010
# Epoch 14/100
# 261/261 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9688
# Epoch 14: val_loss did not improve from 0.30653
# 261/261 [==============================] - 78s 293ms/step - loss: 0.0916 - accuracy: 0.9688 - val_loss: 0.3833 - val_accuracy: 0.9151 - lr: 0.0010
# Epoch 14: early stopping

# %%
### visualizing the model results.
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(14)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Analysis of the result from Model 4
# - Accuracy on validation data has increased to around 96% by using Augmentor library of Python
# - Model is much less overfitting compared to previous models
# - The above model can be further improved by tuning the hyperparameters.
# - Validation loss is also less = 0.38
